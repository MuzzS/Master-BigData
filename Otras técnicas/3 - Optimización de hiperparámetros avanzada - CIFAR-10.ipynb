# %% [markdown]
# # Optimización de hiper-parámetros - Avanzado
#
# En este notebook jugaremos con dos tipos de optimización de hiperparámetros más complicados:
# * Hyperopt
# * Algoritmos genéticos

# %% [markdown]
# ## Hyper-opt
#
# (Hyperopt: Distributed Asynchronous Hyper-parameter Optimization, https://github.com/hyperopt/hyperopt).
#
# Hyperopt es una librería escrita en Python que permite optimizar funciones de una forma rápida fijándose más en los valores que más probablemente van a dar una buena solución.
#
# Actualmente tiene dos algoritmos implementados para hacer esto:
#
# * Random Search
# * Tree of Parzen Estimators (TPE)
#
# Además, se pueden ejecutar en serie o en paralelo, haciendo uso de MongoDB.
#
# Vamos a ver un ejemplo de cómo utilizarlo.
#
# Vamos a encontrar el mínimo de $x^2$:
# (<a href="https://www.google.es/search?source=hp&ei=2ds5XO_jG6y_lwTvxp2QBQ&q=x**2&btnK=Google+Search&oq=x**2&gs_l=psy-ab.3...716.1584..1916...0.0..0.301.1084.1j0j3j1......0....1..gws-wiz.....0..0i131j0.cgRgMW95cQk">click aqui para ver la funcion</a>)

# %%
from hyperopt import fmin, tpe, hp
# con 10 iteraciones

best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=10)

print(best)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 1126.35trial/s, best loss: 1.928737447548943]
# {'x': -1.3887899220360662}

# %%
# con 100 iteraciones
best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=100)

print(best)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 579.87trial/s, best loss: 0.0007544787613054469]
# {'x': -0.027467776781265843}

# %%
# con 1000 iteraciones
best = fmin(fn=lambda x: x ** 2,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            max_evals=1000)

print(best)
# Out:
# 100%|██████████| 1000/1000 [00:09<00:00, 103.24trial/s, best loss: 2.9296773415228777e-08]
# {'x': 0.00017116300247199678}

# %% [markdown]
# Y ahora uno más complejo con redes neuronales:

# %%
# instalamos los paquetes necesarios
# !pip install networkx
# !pip install hyperopt
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.10/dist-packages (0.2.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from hyperopt) (3.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from hyperopt) (4.66.5)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt) (3.1.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt) (0.10.9.7)

# %%
# imports necesarios
import sys
import time
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.constraints import max_norm
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.datasets import cifar10

SEED = 42

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
validation_split = 0.1
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_split, random_state=SEED)

# normalizamos
X_train = X_train.astype('float32') / 255.
X_val = X_val.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.

# convertimos las etiquetas a one-hot encoding
n_classes = 10
y_train = to_categorical(y_train, n_classes)
y_val = to_categorical(y_val, n_classes)
y_test = to_categorical(y_test, n_classes)

# definimos nuestro espacio de búsqueda
# vamos a variar:
# - el número de filtros en nuestras capas conv
# - el porcentaje de dropout
# - el número de neuronas en la capa dense
space = {
    'n_filters_conv': hp.choice('n_filters_conv', [32, 64, 128]),
    'dropout': hp.uniform('dropout', 0.0, 0.5),
    'neurons_dense': hp.choice('neurons_dense', [256, 512, 1024]),
}

def	get_callbacks(pars):
  callbacks	= [EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=0, mode='auto')]
  return callbacks

def mi_cnn(pars):
  print ('Parameters: ', pars)
  model = Sequential()

  # Primer bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Segundo bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Tercer bloque convolucional
  model.add(Conv2D(pars['n_filters_conv'], kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(pars['dropout']))

  # Bloque clasificador
  model.add(Flatten())
  model.add(Dense(pars['neurons_dense'], activation='relu', kernel_constraint=max_norm(3.)))
  model.add(Dropout(pars['dropout']))
  model.add(Dense(10, activation='softmax'))

  # Compilamos el modelo
  model.compile(loss='categorical_crossentropy',
                optimizer=Adam(learning_rate=0.0001),
                metrics=['accuracy'])

  # Entrenamos el modelo
  history = model.fit(X_train,
                      y_train,
                      batch_size=128,
                      shuffle=True,
                      epochs=5,
                      validation_data=(X_val, y_val),
                      verbose = 0,
                      callbacks = get_callbacks(pars))

  best_epoch_loss = np.argmin(history.history['val_loss'])
  best_val_loss = np.min(history.history['val_loss'])
  best_val_acc = np.max(history.history['val_accuracy'])

  print('Epoch {} - val acc: {} - val loss: {}'.format(best_epoch_loss, best_val_acc, best_val_loss))
  sys.stdout.flush()

  return {'loss': best_val_loss, 'best_epoch': best_epoch_loss, 'eval_time': time.time(), 'status': STATUS_OK, 'model': model, 'history': history}


trials = Trials()
best = fmin(mi_cnn, space, algo=tpe.suggest, max_evals=10, trials=trials)
print(best)
# Out:
# Parameters:
# {'dropout': 0.002856169866438607, 'n_filters_conv': 32, 'neurons_dense': 256}
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 4 - val acc: 0.43959999084472656 - val loss: 1.5290528535842896
# Parameters:
# {'dropout': 0.07245362841122666, 'n_filters_conv': 128, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.5551999807357788 - val loss: 1.2591196298599243
# Parameters:
# {'dropout': 0.3363431256666966, 'n_filters_conv': 64, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.4424000084400177 - val loss: 1.5384224653244019
# Parameters:
# {'dropout': 0.4016559700126044, 'n_filters_conv': 128, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.4699999988079071 - val loss: 1.4867347478866577
# Parameters:
# {'dropout': 0.08342168971332214, 'n_filters_conv': 128, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.5569999814033508 - val loss: 1.2521369457244873
# Parameters:
# {'dropout': 0.11954843290484468, 'n_filters_conv': 32, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.4352000057697296 - val loss: 1.5349242687225342
# Parameters:
# {'dropout': 0.292611717598086, 'n_filters_conv': 64, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.4027999937534332 - val loss: 1.6205567121505737
# Parameters:
# {'dropout': 0.10343165802913512, 'n_filters_conv': 32, 'neurons_dense': 256}
# Epoch 4 - val acc: 0.4075999855995178 - val loss: 1.5966284275054932
# Parameters:
# {'dropout': 0.14752393622930876, 'n_filters_conv': 32, 'neurons_dense': 1024}
# Epoch 4 - val acc: 0.40560001134872437 - val loss: 1.620054006576538
# Parameters:
# {'dropout': 0.2449077618295477, 'n_filters_conv': 64, 'neurons_dense': 512}
# Epoch 4 - val acc: 0.45239999890327454 - val loss: 1.501205563545227
# 100%|██████████| 10/10 [04:32<00:00, 27.24s/trial, best loss: 1.2521369457244873]
# {'dropout': 0.08342168971332214, 'n_filters_conv': 2, 'neurons_dense': 2}

# %%
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': 1.5290528535842896,
#    'best_epoch': 4,
#    'eval_time': 1729523012.2184694,
#    'status': 'ok',
#    'model': <Sequential name=sequential, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dee5d2b9420>},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [0], 'n_filters_conv': [0], 'neurons_dense': [0]},
#    'vals': {'dropout': [0.002856169866438607],
#     'n_filters_conv': [0],
#     'neurons_dense': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 3, 9, 105000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 3, 32, 218000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': 1.2591196298599243,
#    'best_epoch': 4,
#    'eval_time': 1729523051.1704674,
#    'status': 'ok',
#    'model': <Sequential name=sequential_1, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dee59146da0>},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [1], 'n_filters_conv': [1], 'neurons_dense': [1]},
#    'vals': {'dropout': [0.07245362841122666],
#     'n_filters_conv': [2],
#     'neurons_dense': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 3, 32, 222000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 4, 11, 170000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': 1.5384224653244019,
#    'best_epoch': 4,
#    'eval_time': 1729523074.410081,
#    'status': 'ok',
#    'model': <Sequential name=sequential_2, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dee585d5300>},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [2], 'n_filters_conv': [2], 'neurons_dense': [2]},
#    'vals': {'dropout': [0.3363431256666966],
#     'n_filters_conv': [1],
#     'neurons_dense': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 4, 11, 174000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 4, 34, 410000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': 1.4867347478866577,
#    'best_epoch': 4,
#    'eval_time': 1729523108.533878,
#    'status': 'ok',
#    'model': <Sequential name=sequential_3, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dee52b1aaa0>},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [3], 'n_filters_conv': [3], 'neurons_dense': [3]},
#    'vals': {'dropout': [0.4016559700126044],
#     'n_filters_conv': [2],
#     'neurons_dense': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 4, 34, 414000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 5, 8, 533000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': 1.2521369457244873,
#    'best_epoch': 4,
#    'eval_time': 1729523143.7574413,
#    'status': 'ok',
#    'model': <Sequential name=sequential_4, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dee527a8b80>},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [4], 'n_filters_conv': [4], 'neurons_dense': [4]},
#    'vals': {'dropout': [0.08342168971332214],
#     'n_filters_conv': [2],
#     'neurons_dense': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 5, 8, 538000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 5, 43, 757000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': 1.5349242687225342,
#    'best_epoch': 4,
#    'eval_time': 1729523164.1804953,
#    'status': 'ok',
#    'model': <Sequential name=sequential_5, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dee1c40d750>},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [5], 'n_filters_conv': [5], 'neurons_dense': [5]},
#    'vals': {'dropout': [0.11954843290484468],
#     'n_filters_conv': [0],
#     'neurons_dense': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 5, 43, 761000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 6, 4, 180000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': 1.6205567121505737,
#    'best_epoch': 4,
#    'eval_time': 1729523187.2757509,
#    'status': 'ok',
#    'model': <Sequential name=sequential_6, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dee52b19960>},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [6], 'n_filters_conv': [6], 'neurons_dense': [6]},
#    'vals': {'dropout': [0.292611717598086],
#     'n_filters_conv': [1],
#     'neurons_dense': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 6, 4, 185000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 6, 27, 275000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': 1.5966284275054932,
#    'best_epoch': 4,
#    'eval_time': 1729523206.852611,
#    'status': 'ok',
#    'model': <Sequential name=sequential_7, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dee10188f70>},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [7], 'n_filters_conv': [7], 'neurons_dense': [7]},
#    'vals': {'dropout': [0.10343165802913512],
#     'n_filters_conv': [0],
#     'neurons_dense': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 6, 27, 279000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 6, 46, 852000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': 1.620054006576538,
#    'best_epoch': 4,
#    'eval_time': 1729523229.1467323,
#    'status': 'ok',
#    'model': <Sequential name=sequential_8, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dedc3df6b30>},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [8], 'n_filters_conv': [8], 'neurons_dense': [8]},
#    'vals': {'dropout': [0.14752393622930876],
#     'n_filters_conv': [0],
#     'neurons_dense': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 6, 46, 857000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 7, 9, 146000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': 1.501205563545227,
#    'best_epoch': 4,
#    'eval_time': 1729523261.5266478,
#    'status': 'ok',
#    'model': <Sequential name=sequential_9, built=True>,
#    'history': <keras.src.callbacks.history.History at 0x7dedae263f10>},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'dropout': [9], 'n_filters_conv': [9], 'neurons_dense': [9]},
#    'vals': {'dropout': [0.2449077618295477],
#     'n_filters_conv': [1],
#     'neurons_dense': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 21, 15, 7, 9, 151000),
#   'refresh_time': datetime.datetime(2024, 10, 21, 15, 7, 41, 526000)}]

# %% [markdown]
# ¿Por qué dice que best_epoch=4? Porque history está indexado en 0.

# %%
trials.trials[6]
# Out:
# {'state': 2,
#  'tid': 6,
#  'spec': None,
#  'result': {'loss': 1.6205567121505737,
#   'best_epoch': 4,
#   'eval_time': 1729523187.2757509,
#   'status': 'ok',
#   'model': <Sequential name=sequential_6, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dee52b19960>},
#  'misc': {'tid': 6,
#   'cmd': ('domain_attachment', 'FMinIter_Domain'),
#   'workdir': None,
#   'idxs': {'dropout': [6], 'n_filters_conv': [6], 'neurons_dense': [6]},
#   'vals': {'dropout': [0.292611717598086],
#    'n_filters_conv': [1],
#    'neurons_dense': [0]}},
#  'exp_key': None,
#  'owner': None,
#  'version': 0,
#  'book_time': datetime.datetime(2024, 10, 21, 15, 6, 4, 185000),
#  'refresh_time': datetime.datetime(2024, 10, 21, 15, 6, 27, 275000)}

# %%
trials.results
# Out:
# [{'loss': 1.5290528535842896,
#   'best_epoch': 4,
#   'eval_time': 1729523012.2184694,
#   'status': 'ok',
#   'model': <Sequential name=sequential, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dee5d2b9420>},
#  {'loss': 1.2591196298599243,
#   'best_epoch': 4,
#   'eval_time': 1729523051.1704674,
#   'status': 'ok',
#   'model': <Sequential name=sequential_1, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dee59146da0>},
#  {'loss': 1.5384224653244019,
#   'best_epoch': 4,
#   'eval_time': 1729523074.410081,
#   'status': 'ok',
#   'model': <Sequential name=sequential_2, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dee585d5300>},
#  {'loss': 1.4867347478866577,
#   'best_epoch': 4,
#   'eval_time': 1729523108.533878,
#   'status': 'ok',
#   'model': <Sequential name=sequential_3, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dee52b1aaa0>},
#  {'loss': 1.2521369457244873,
#   'best_epoch': 4,
#   'eval_time': 1729523143.7574413,
#   'status': 'ok',
#   'model': <Sequential name=sequential_4, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dee527a8b80>},
#  {'loss': 1.5349242687225342,
#   'best_epoch': 4,
#   'eval_time': 1729523164.1804953,
#   'status': 'ok',
#   'model': <Sequential name=sequential_5, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dee1c40d750>},
#  {'loss': 1.6205567121505737,
#   'best_epoch': 4,
#   'eval_time': 1729523187.2757509,
#   'status': 'ok',
#   'model': <Sequential name=sequential_6, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dee52b19960>},
#  {'loss': 1.5966284275054932,
#   'best_epoch': 4,
#   'eval_time': 1729523206.852611,
#   'status': 'ok',
#   'model': <Sequential name=sequential_7, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dee10188f70>},
#  {'loss': 1.620054006576538,
#   'best_epoch': 4,
#   'eval_time': 1729523229.1467323,
#   'status': 'ok',
#   'model': <Sequential name=sequential_8, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dedc3df6b30>},
#  {'loss': 1.501205563545227,
#   'best_epoch': 4,
#   'eval_time': 1729523261.5266478,
#   'status': 'ok',
#   'model': <Sequential name=sequential_9, built=True>,
#   'history': <keras.src.callbacks.history.History at 0x7dedae263f10>}]

# %%
trials.losses()
# Out:
# [1.5290528535842896,
#  1.2591196298599243,
#  1.5384224653244019,
#  1.4867347478866577,
#  1.2521369457244873,
#  1.5349242687225342,
#  1.6205567121505737,
#  1.5966284275054932,
#  1.620054006576538,
#  1.501205563545227]

# %% [markdown]
# Qué os parece? mola eh? Así, podéis dejar vuestra configuración e iros a hacer algo más útil que andar variando parámetros hasta que encontréis la configuración adecuada.
#
# **Mejor que lo hagan por nosotros y que nos la encontremos automáticamente seleccionada!**
#
# Pero no tenemos por qué quedarnos aquí, podemos también variar el número de capas o si queremos conexiones residuales, por ejemplo! Sí, esto significa que podemos variar la **arquitectura** también!!
#
# Aquí tenéis un ejemplo muy completo: https://github.com/Vooban/Hyperopt-Keras-CNN-CIFAR-100
#
# Y aquí otro que quizá os parezca interesante:
#
# <img src="http://cdn.lizamayliza.com/storage/cache/images/003/636/Daffy-Duck-Money-eyes-feature,xlarge.1480369578.jpg" border="0" height="200">
#
# https://medium.com/machine-learning-world/neural-networks-for-algorithmic-trading-hyperparameters-optimization-cb2b4a29b8ee

# %% [markdown]
# ## 6.3 Algoritmos genéticos
#
# Quizás estéis pensando en que tras haber visto esto no necesitáis saber nada más, ya habéis encontrado algo que es la repera! Pues atentos porque lo que viene, pese a ser algo muy sencillo, es potentísimo, y os va encantar. Sí, estoy hablando de **los algoritmos genéticos**.
#
# En esencia, los algoritmos genéticos son un método de búsqueda meta-heurística inspirados en la evolución natural. Pertenecen a los algoritmos evolutivos, concretamente a los Algoritmos de búsqueda aleatoria guiada (Guided Random Search algorithms (Evolutionary Alg.)).
#
# Esto que os puede parecer chino, es muy sencillo. Vamos a entenderlos con un ejemplo:
#
# <img src="https://image.ibb.co/cJcQYJ/ga_problem.png" alt="ga_problem" border="0">
#
# Imaginad que tenemos un puzzle, y nos queda solo una pieza por encajar. Lo que pasa es que este puzzle es muy especial, porque nos permite fabricarnos nuestras propias piezas. Para ello, disponemos de varios mecanismos:
#
# * **combinar** partes de piezas (**crossover** o recombinación)
# * **modificar** determinadas partes de esas piezas (**mutación**)
# * **escoger** las mejores piezas de todas las que hemos hecho, para a partir de ellas, construir nuevas que sean mejores (**selección**)
#
# Entonces imaginaos que decidimos cortar 10 trozos de carton, que son nuestras 10 piezas iniciales con las que vamos a probar a ver si alguna encaja perfectamnte. Las probamos todas, y de esas 10, 5 encajan más o menos. Así que seleccionamos esas 5 y fabricamos nuevas a partir de ellas mediante los mecanismos explicados arriba:
#
# * de las 5 seleccionadas, sacamos 5 más combinando partes de dos de esas 5 originales escogiéndolas aleatoriamente
# * de las 5 originales, y las nuevas 5 que nos hemos creado, sacamos 5 más modificando ligeramente una de las puntas de la pieza
#
# Ahora resulta que tenemos 15 piezas, y nosotros queremos tener siempre 10, porque si no a la 5 vez que hiciéramos esto tendríamos una barbaridad de piezas!! Así que:
#
# * probamos nuestras 15 piezas y nos quedamos con la que mejor encaja, y luego 9 escogidas al azar
#
# Pues ya está, eso es lo que hace un algoritmo genético!! Ya sabéis cómo funcionan!! Sencillo, verdad? Pues no os hacéis una idea de lo potentes que son :-)
#
# Vamos a verlo un poco más concreto siguiendo con nuestro ejemplo:
#
# <img src="https://image.ibb.co/b7ySfy/geneticos_puzzle.png" alt="geneticos_puzzle" border="0">
#
# Como podéis ver:
#
# * cada pieza de nuestro conjunto de piezas (población) es un **cromosoma**
# * cada parte de nuestra pieza es un **gen**, por tanto, nuestro cromosoma tiene 4 genes
# * los posibles valores o configuraciones que puede tener cada gen se llama **alelo**
#
# Esto es exactamente igual que en biología! No os dije que estaban inspirados en la evolución natural? :-)
#
# Vale, pues vamos a ir relacionando estas palabrejas con nuestro ejemplo:
#
# * necesitamos encontrar la pieza correcta para nuestro hueco del puzzle
# * tenemos un conjunto inicial de piezas (**población**) que pueden encajar bien o no, no lo sabemos
# * comprobamos cómo de bien encajan estas piezas (usando la **función de fitness**)
# * si ninguna de las piezas encaja como nos gustaría, modificamos las piezas (con los operadores: **crossover** y **mutación**)
# * comprobamos como de bien encajan las piezas recien creadas (**función de fitness**)
# * seleccionamos las piezas que queremos aguantar para la próxima iteración (**selección**)
#
# * y volvemos a empezar! así, hasta que enocntremos una pieza que encaje con la precisión que nosotros queremos
#
# Venga, vamos a ponernos un poco más serios. Veamos el pseudo-algoritmo:
#
# **START**
#
# Generate the initial population
#
# Compute fitness
#
# **REPEAT**
#
#     Selection
#
#     Crossover
#
#     Mutation
#
#     Compute fitness
#
# **UNTIL** population has converged
#
# **STOP**
#
# Se entiende, no? Es exactamente lo mismo que los pasos que acabamos de hablar con el puzzle!!
#
# <img src="https://image.ibb.co/kQu7Ed/ga_workflow.png" alt="ga_workflow" border="0" width="600">
#
# Vale, y ahora llega lo interesante, cómo funcionan realmente?
#
# Tenemos que entender varios conceptos:
#
# * cómo se inicializa nuestra población
# * cómo funciona el crossover
# * cómo funciona la mutación
# * cómo funciona la seleccion
# * cómo podemos definir nuestra función de fitness
#
# Preparados? Vamos allá!

# %% [markdown]
# Lo primero es entender que cuando tenemos un problema en el mundo real y queremos solucionarlo en un ordenador, necesitamos **codificarlo** para que el ordenador lo entienda.
#
# Así, por ejemplo:
#
# * En el mundo real, el cromosoma es la pieza del puzzle. En el ordenador, el cromosoma es un vector con 4 valores (uno para indicar el tamaño de cada punta, donde positivo significa punta, negativo significa hueco hacia dentro de la pieza)
#
# Esto es a lo que se llama la codificación.
#
# Una vez sabido esto, vamos a ver cómo funcionan los operadores. Antes de nada, debéis saber que xisten muchos tipos de crossover, mutación y selección, pero aquí vamos a ver solo los más sencillos por temas de tiempo.
#
# Si estáis interesados en conocerlos más profundamente, en internet hay muchísimo material disponible. Podéis empezar aquí: https://www.tutorialspoint.com/genetic_algorithms/index.htm
#
# Vale, al turrón!
#
# <img src="https://image.ibb.co/hEwVHd/ga_operators.png" alt="ga_operators" border="0">
#
# **El crossover de un único punto (single-point crossover)**
#
# Nuestro cromosoma es la pieza de puzzle, que tiene los 4 genes que veis en la imagen. Pues el crossover simple sencillamente escoge un punto aleatoriamente de los 4 genes, y combina las partes en nuevos cromosomas, como veis en la imagen.
#
# Es importante que entendáis que el crossover **produce nuevos cromosomas**, puesto que tenemos los originales y los **recombinados**.
#
# **La mutación uniforme**
#
# La mutación uniforme consiste en que para cada cromosoma, lanzamos una moneda al aire. Si sale cara, modificamos un gen escogido aleatoriamente. ¿Qué valor le asignamos? Uno aleatorio dentro del rango que permite dicho gen.
#
# **La selección**
#
# Para la selección lo que se suele hacer es usar las fitness de los cromosomas (también llamados posibles **soluciones**). En este caso, vamos a ver la Stochastic Universal Sampling, que consiste en que construímos una gráfica de tipo tarta donde cada cromosoma ocupa un espacio que corresponde con su fitness. Después, establecemos N puntos fijos alrededor de la "tarta", donde N son el número de cromomsomas que queremos **seleccionar**. Después, se "gira la tarta", como si fuese la ruleta de la suerte, y los cromosomas a los que apuntan los puntos fijos son los seleccionados y pasan a la siguiente iteración.
#
# Si os fijáis, **los cromosomas no están ordenados de mayor a menor fitness**!!
#
# Esto es importante, puesto que si no, las probabilidades de seleccionar un cromosoma con una fitness alta y otro con una fitness baja serían más altas que de seleccionar dos con la fitness alta, ya que al estar los puntos de selección uno enfrente del otro, sería muy complicado seleccionar dos cromosomas con fitness parecidas.
#
# Este operador tiene varias formas de funcionar. Siguiendo con nuestro ejemplo de población de 10 cromosomas, las formas son:
#
# * Seleccionamos $N=10$ cromosomas, es decir, sustituimos la anterior población por una completamente nueva
# * Seleccionamos $N=n$ cromosomas, donde n<10. Es decir, sustituímos solo una parte de los crosomomas antiguos. El resto siguen jugando ;-D
#
# Vale, pues si seleccionamos los 10 está claro, pero si seleccionamos $n$, cómo elegimos cuales quitamos?
#
# Pues las dos formas más comunes son:
#
# * Quitamos los cromosomas más antiguos
# * Quitamos los cromosomas con peor fitness
#
# Ya por último, hay veces que seleccionamos al mejor cromosoma (o a los $k$ mejors) para que pase si o si a la siguiente iteración, es decir, hay *elitismo*. Hay que ir con cuidado con esto, puesto que aunque a priori parezca que el elitismo es lo mejor y que solo deberíamos quedarnos con los mejores, si lo hiciésemos nos estaríamos cargando una de las mayores virtudes de los genéticos: **que son capaces de escapar a mínimos locales!!!**
#
# Fijaos, aquí podéis ver en plena acción a un genético intentando decidir cual es la mejor configuración para un vehículo de 2 ruedas: http://rednuht.org/genetic_cars_2/
#
# Curioso, eh?
#
# Vale, pues ahora qué tal si implementamos un par de ejemplos nosotros?

# %%
# ejemplo simple de un GA donde tenemos que encontrar N números que sumen X
# https://lethain.com/genetic-algorithms-cool-name-damn-simple

from random import randint, random
from operator import add
from functools import reduce
import numpy as np

def individual(length, min, max):
    # creamos un individuo
    return [ randint(min,max) for x in range(length) ]

def population(count, length, min, max):
    # creamos nuestra población
    # count: numero de invidiuos en la población
    # length: número de valores por individuo
    # min: minimo permitido para cada valor del individuo
    # max: maximo permitido para cada valor del individuo

    return [ individual(length, min, max) for x in range(count) ]

def fitness(individual, target):
    # calculamos la fitness de un individuo: más bajo es mejor

    sum = reduce(add, individual, 0)
    return abs(target-sum)

def grade(pop, target):
    # calculamos la media de la población entera
    summed = reduce(add, (fitness(x, target) for x in pop))
    return summed / (len(pop) * 1.0)

def find_best_solution(pop, target):
    # encuentra la mejor solución en la población actual y la imprime
    res = [fitness(x, target) for x in pop]
    res_min = np.min(res)
    res_min_idx = np.where(res == res_min)[0]
    for n in res_min_idx:
        print('Individual: ', n, 'Valores: ', *pop[n], ' Result: ', np.sum(pop[n]), 'Target; ', target)
    return res_min

def evolve(pop, target, retain=0.2, random_select=0.05, mutate=0.01):
    graded = [ (fitness(x, target), x) for x in pop]
    graded = [ x[1] for x in sorted(graded)]
    retain_length = int(len(graded)*retain)
    parents = graded[:retain_length]

    # añadimos individuos aleatoriamente para promover la diversidad genética
    for individual in graded[retain_length:]:
        if random_select > random():
            parents.append(individual)

    # mutamos algunos
    for individual in parents:
        if mutate > random():
            pos_to_mutate = randint(0, len(individual)-1)
            individual[pos_to_mutate] = randint(i_min, i_max)

    # reproducimos (crossover) nuestros cromosomas (individuals, soluciones)
    parents_length = len(parents)
    desired_length = len(pop) - parents_length
    children = []
    while len(children) < desired_length:
        male = randint(0, parents_length-1)
        female = randint(0, parents_length-1)
        if male != female:
            male = parents[male]
            female = parents[female]
            half = round(len(male) / 2)
            child = male[:half] + female[half:]
            children.append(child)
    parents.extend(children)
    return parents

# ejecutamos el GA
generations = 200
target = 108
p_count = 20
i_length = 10
i_min = 0
i_max = 100
error_accepted = 1
print('Inicializamos la población con 20 individuos.')
p = population(p_count, i_length, i_min, i_max)
print('Calculamos el fitness de esos 20 individuos.')
fitness_history = [grade(p, target),]
print('El mejor individuo de la población inicial es:')
find_best_solution(p, target)

print('Comienza la búsqueda:')
for i in range(generations):
    p = evolve(p, target, retain=0.2, random_select=0.4, mutate=0.4)
    res = grade(p, target)
    fitness_history.append(res)

    res_min = find_best_solution(p, target)
    print('Generación: ', i, ' Fitness medio de todos los individuos de la población:', res)

    if res_min < error_accepted:
      break
# Out:
# Inicializamos la población con 20 individuos.
# Calculamos el fitness de esos 20 individuos.
# El mejor individuo de la población inicial es:
# Individual:  14 Valores:  66 1 84 27 19 12 65 52 10 42  Result:  378 Target;  108
# Comienza la búsqueda:
# Individual:  3 Valores:  6 76 45 31 1 2 0 90 32 67  Result:  350 Target;  108
# Generación:  0  Fitness medio de todos los individuos de la población: 419.45
# Individual:  0 Valores:  6 76 45 31 1 2 0 90 32 67  Result:  350 Target;  108
# Individual:  18 Valores:  6 76 45 31 1 2 0 90 32 67  Result:  350 Target;  108
# Generación:  1  Fitness medio de todos los individuos de la población: 387.5
# Individual:  0 Valores:  6 76 45 31 1 2 0 90 32 67  Result:  350 Target;  108
# Individual:  1 Valores:  6 76 45 31 1 2 0 90 32 67  Result:  350 Target;  108
# Generación:  2  Fitness medio de todos los individuos de la población: 376.3
# Individual:  0 Valores:  6 76 45 31 1 2 0 90 32 67  Result:  350 Target;  108
# Individual:  1 Valores:  6 76 45 31 1 2 0 90 32 67  Result:  350 Target;  108
# Generación:  3  Fitness medio de todos los individuos de la población: 367.0
# Individual:  2 Valores:  7 30 10 55 37 2 0 90 32 67  Result:  330 Target;  108
# Generación:  4  Fitness medio de todos los individuos de la población: 349.8
# Individual:  0 Valores:  7 30 10 55 37 2 0 90 32 67  Result:  330 Target;  108
# Generación:  5  Fitness medio de todos los individuos de la población: 327.85
# Individual:  0 Valores:  7 30 10 55 37 2 0 90 32 67  Result:  330 Target;  108
# Individual:  15 Valores:  7 30 10 55 37 2 0 90 32 67  Result:  330 Target;  108
# Individual:  16 Valores:  7 30 10 55 37 2 0 90 32 67  Result:  330 Target;  108
# Generación:  6  Fitness medio de todos los individuos de la población: 311.5
# Individual:  16 Valores:  7 30 10 55 37 2 0 65 32 67  Result:  305 Target;  108
# Generación:  7  Fitness medio de todos los individuos de la población: 278.9
# Individual:  17 Valores:  7 30 10 55 37 2 0 27 32 67  Result:  267 Target;  108
# Generación:  8  Fitness medio de todos los individuos de la población: 257.1
# Individual:  18 Valores:  7 30 10 55 37 2 20 5 32 67  Result:  265 Target;  108
# Generación:  9  Fitness medio de todos los individuos de la población: 235.4
# Individual:  0 Valores:  7 30 10 55 37 2 20 5 32 67  Result:  265 Target;  108
# Generación:  10  Fitness medio de todos los individuos de la población: 239.9
# Individual:  1 Valores:  7 30 10 20 37 2 0 27 32 67  Result:  232 Target;  108
# Generación:  11  Fitness medio de todos los individuos de la población: 214.45
# Individual:  17 Valores:  7 30 10 20 37 2 0 27 32 67  Result:  232 Target;  108
# Generación:  12  Fitness medio de todos los individuos de la población: 219.7
# Individual:  0 Valores:  7 30 10 20 37 2 0 27 32 67  Result:  232 Target;  108
# Generación:  13  Fitness medio de todos los individuos de la población: 233.0
# Individual:  0 Valores:  7 30 10 20 37 2 0 27 32 67  Result:  232 Target;  108
# Generación:  14  Fitness medio de todos los individuos de la población: 202.9
# Individual:  0 Valores:  7 30 10 20 37 2 0 27 32 67  Result:  232 Target;  108
# Generación:  15  Fitness medio de todos los individuos de la población: 176.15
# Individual:  1 Valores:  7 30 10 20 37 2 20 5 32 14  Result:  177 Target;  108
# Generación:  16  Fitness medio de todos los individuos de la población: 164.65
# Individual:  12 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  19 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Generación:  17  Fitness medio de todos los individuos de la población: 175.0
# Individual:  0 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  1 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  9 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  15 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Generación:  18  Fitness medio de todos los individuos de la población: 163.3
# Individual:  0 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  1 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  3 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  8 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  9 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  10 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Individual:  16 Valores:  7 30 10 20 37 63 20 5 32 14  Result:  238 Target;  108
# Generación:  19  Fitness medio de todos los individuos de la población: 149.2
# Individual:  16 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Individual:  19 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Generación:  20  Fitness medio de todos los individuos de la población: 140.55
# Individual:  0 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Individual:  1 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Individual:  17 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Generación:  21  Fitness medio de todos los individuos de la población: 146.15
# Individual:  1 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Individual:  2 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Individual:  13 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Individual:  15 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Individual:  16 Valores:  7 30 10 20 37 39 20 5 32 14  Result:  214 Target;  108
# Generación:  22  Fitness medio de todos los individuos de la población: 150.35
# Individual:  0 Valores:  7 30 10 20 37 3 20 5 32 14  Result:  178 Target;  108
# Individual:  15 Valores:  7 30 10 20 37 3 20 5 32 14  Result:  178 Target;  108
# Generación:  23  Fitness medio de todos los individuos de la población: 154.65
# Individual:  0 Valores:  7 30 10 20 37 3 20 5 6 14  Result:  152 Target;  108
# Generación:  24  Fitness medio de todos los individuos de la población: 167.7
# Individual:  0 Valores:  7 30 10 20 37 3 20 5 6 14  Result:  152 Target;  108
# Generación:  25  Fitness medio de todos los individuos de la población: 152.3
# Individual:  2 Valores:  7 30 10 20 8 3 20 5 32 14  Result:  149 Target;  108
# Generación:  26  Fitness medio de todos los individuos de la población: 142.65
# Individual:  0 Valores:  7 30 10 20 8 3 20 5 32 14  Result:  149 Target;  108
# Generación:  27  Fitness medio de todos los individuos de la población: 170.7
# Individual:  0 Valores:  7 30 10 20 8 3 20 5 32 14  Result:  149 Target;  108
# Generación:  28  Fitness medio de todos los individuos de la población: 191.85
# Individual:  0 Valores:  7 30 10 20 8 3 20 5 32 14  Result:  149 Target;  108
# Generación:  29  Fitness medio de todos los individuos de la población: 170.75
# Individual:  1 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Generación:  30  Fitness medio de todos los individuos de la población: 149.35
# Individual:  0 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Generación:  31  Fitness medio de todos los individuos de la población: 136.2
# Individual:  0 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Generación:  32  Fitness medio de todos los individuos de la población: 112.7
# Individual:  10 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Individual:  12 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Individual:  13 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Generación:  33  Fitness medio de todos los individuos de la población: 91.05
# Individual:  0 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Individual:  1 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Individual:  16 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Generación:  34  Fitness medio de todos los individuos de la población: 103.35
# Individual:  1 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Individual:  2 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Individual:  8 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Individual:  10 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Generación:  35  Fitness medio de todos los individuos de la población: 85.2
# Individual:  1 Valores:  7 30 10 20 0 21 8 5 6 14  Result:  121 Target;  108
# Generación:  36  Fitness medio de todos los individuos de la población: 81.85
# Individual:  0 Valores:  7 30 10 20 0 21 8 5 6 14  Result:  121 Target;  108
# Generación:  37  Fitness medio de todos los individuos de la población: 82.85
# Individual:  0 Valores:  7 30 10 20 0 21 8 5 6 14  Result:  121 Target;  108
# Generación:  38  Fitness medio de todos los individuos de la población: 89.45
# Individual:  0 Valores:  7 30 10 20 0 21 8 5 6 14  Result:  121 Target;  108
# Individual:  16 Valores:  7 30 10 20 0 21 8 5 6 14  Result:  121 Target;  108
# Generación:  39  Fitness medio de todos los individuos de la población: 79.8
# Individual:  0 Valores:  7 30 10 20 0 21 8 5 6 14  Result:  121 Target;  108
# Generación:  40  Fitness medio de todos los individuos de la población: 91.8
# Individual:  1 Valores:  7 30 10 20 2 21 8 5 6 14  Result:  123 Target;  108
# Generación:  41  Fitness medio de todos los individuos de la población: 121.0
# Individual:  1 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Individual:  18 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Generación:  42  Fitness medio de todos los individuos de la población: 112.95
# Individual:  1 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Individual:  18 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Generación:  43  Fitness medio de todos los individuos de la población: 81.0
# Individual:  19 Valores:  7 30 10 20 0 21 20 5 6 14  Result:  133 Target;  108
# Generación:  44  Fitness medio de todos los individuos de la población: 63.5
# Individual:  6 Valores:  7 30 10 20 0 13 20 5 6 14  Result:  125 Target;  108
# Generación:  45  Fitness medio de todos los individuos de la población: 66.4
# Individual:  1 Valores:  7 30 10 20 2 6 20 5 6 14  Result:  120 Target;  108
# Generación:  46  Fitness medio de todos los individuos de la población: 77.85
# Individual:  0 Valores:  7 30 10 20 2 6 20 5 6 14  Result:  120 Target;  108
# Generación:  47  Fitness medio de todos los individuos de la población: 84.25
# Individual:  2 Valores:  7 30 10 20 0 13 8 5 6 14  Result:  113 Target;  108
# Generación:  48  Fitness medio de todos los individuos de la población: 117.0
# Individual:  1 Valores:  7 30 10 20 2 6 20 5 6 14  Result:  120 Target;  108
# Generación:  49  Fitness medio de todos los individuos de la población: 114.2
# Individual:  0 Valores:  7 26 10 20 2 6 20 5 6 14  Result:  116 Target;  108
# Generación:  50  Fitness medio de todos los individuos de la población: 119.15
# Individual:  0 Valores:  7 26 10 20 2 6 20 5 6 14  Result:  116 Target;  108
# Individual:  13 Valores:  7 26 10 20 2 6 20 5 6 14  Result:  116 Target;  108
# Generación:  51  Fitness medio de todos los individuos de la población: 120.5
# Individual:  0 Valores:  7 26 10 20 2 6 20 5 6 14  Result:  116 Target;  108
# Individual:  1 Valores:  7 26 10 20 2 6 20 5 6 14  Result:  116 Target;  108
# Individual:  12 Valores:  7 26 10 20 2 6 20 5 6 14  Result:  116 Target;  108
# Individual:  16 Valores:  7 26 10 20 2 6 20 5 6 14  Result:  116 Target;  108
# Generación:  52  Fitness medio de todos los individuos de la población: 103.15
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  53  Fitness medio de todos los individuos de la población: 97.4
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  54  Fitness medio de todos los individuos de la población: 38.15
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  12 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  13 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  55  Fitness medio de todos los individuos de la población: 41.05
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  3 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  56  Fitness medio de todos los individuos de la población: 33.5
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  15 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  57  Fitness medio de todos los individuos de la población: 40.4
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  18 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  58  Fitness medio de todos los individuos de la población: 42.45
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  59  Fitness medio de todos los individuos de la población: 42.35
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  17 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  60  Fitness medio de todos los individuos de la población: 52.95
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  15 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  17 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  61  Fitness medio de todos los individuos de la población: 45.75
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  13 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  62  Fitness medio de todos los individuos de la población: 40.7
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  13 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Individual:  18 Valores:  7 26 10 20 2 2 20 5 6 14  Result:  112 Target;  108
# Generación:  63  Fitness medio de todos los individuos de la población: 54.1
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  18 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  64  Fitness medio de todos los individuos de la población: 57.2
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  65  Fitness medio de todos los individuos de la población: 73.7
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  18 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  66  Fitness medio de todos los individuos de la población: 52.7
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  67  Fitness medio de todos los individuos de la población: 75.75
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  10 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  68  Fitness medio de todos los individuos de la población: 40.15
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  17 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  18 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  69  Fitness medio de todos los individuos de la población: 50.25
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  3 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  4 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  10 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  11 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  12 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  15 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  17 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  70  Fitness medio de todos los individuos de la población: 26.35
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  15 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  17 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  71  Fitness medio de todos los individuos de la población: 41.7
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  3 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  11 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  17 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  72  Fitness medio de todos los individuos de la población: 52.15
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  3 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  10 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  11 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  17 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  73  Fitness medio de todos los individuos de la población: 46.3
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  3 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  4 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  12 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Generación:  74  Fitness medio de todos los individuos de la población: 55.7
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  4 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  9 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  17 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  75  Fitness medio de todos los individuos de la población: 64.55
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  3 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  4 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  10 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  12 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  16 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  18 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Generación:  76  Fitness medio de todos los individuos de la población: 49.85
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  1 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  4 Valores:  7 26 10 20 2 2 20 5 6 12  Result:  110 Target;  108
# Individual:  13 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  19 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Generación:  77  Fitness medio de todos los individuos de la población: 63.8
# Individual:  3 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  16 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Generación:  78  Fitness medio de todos los individuos de la población: 89.85
# Individual:  0 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  13 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  14 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Individual:  17 Valores:  7 26 10 20 2 2 20 5 6 8  Result:  106 Target;  108
# Generación:  79  Fitness medio de todos los individuos de la población: 107.2
# Individual:  0 Valores:  7 26 10 20 2 2 20 7 6 8  Result:  108 Target;  108
# Individual:  2 Valores:  7 26 10 20 2 2 20 5 8 8  Result:  108 Target;  108
# Generación:  80  Fitness medio de todos los individuos de la población: 84.35

# %%
# Ejemplo un poco más complejo de un GA que tiene que encontrar la cadena 'Hello Word!'
# http://www.obitko.com/tutorials/genetic-algorithms/ga-basic-description.php

import random

class GeneticAlgorithm(object):
    def __init__(self, genetics):
        self.genetics = genetics
        pass

    def run(self):
        population = self.genetics.initial()
        while True:
            fits_pops = [(self.genetics.fitness(ch),  ch) for ch in population]
            if self.genetics.check_stop(fits_pops): break
            population = self.next(fits_pops)
            pass
        return population

    def next(self, fits):
        parents_generator = self.genetics.parents(fits)
        size = len(fits)
        nexts = []
        while len(nexts) < size:
            parents = next(parents_generator)
            cross = random.random() < self.genetics.probability_crossover()
            children = self.genetics.crossover(parents) if cross else parents
            for ch in children:
                mutate = random.random() < self.genetics.probability_mutation()
                nexts.append(self.genetics.mutation(ch) if mutate else ch)
                pass
            pass
        return nexts[0:size]
    pass

class GeneticFunctions(object):
    def probability_crossover(self):
        # returns rate of occur crossover(0.0-1.0)
        return 1.0

    def probability_mutation(self):
        # returns rate of occur mutation(0.0-1.0)
        return 0.0

    def initial(self):
        # returns list of initial population
        return []

    def fitness(self, chromosome):
        # returns domain fitness value of chromosome
        return len(chromosome)

    def check_stop(self, fits_populations):
        # stop run if returns True
        # - fits_populations: list of (fitness_value, chromosome)
        return False

    def parents(self, fits_populations):
        r"""generator of selected parents
        """
        gen = iter(sorted(fits_populations))
        while True:
            f1, ch1 = next(gen)
            f2, ch2 = next(gen)
            yield (ch1, ch2)
            pass
        return

    def crossover(self, parents):
        r"""breed children
        """
        return parents

    def mutation(self, chromosome):
        r"""mutate chromosome
        """
        return chromosome
    pass

if __name__ == "__main__":
    """
    example: Mapped guess prepared Text
    """
    class GuessText(GeneticFunctions):
        def __init__(self, target_text,
                     limit=200, size=400,
                     prob_crossover=0.9, prob_mutation=0.2):
            self.target = self.text2chromo(target_text)
            self.counter = 0

            self.limit = limit
            self.size = size
            self.prob_crossover = prob_crossover
            self.prob_mutation = prob_mutation
            pass

        # GeneticFunctions interface impls
        def probability_crossover(self):
            return self.prob_crossover

        def probability_mutation(self):
            return self.prob_mutation

        def initial(self):
            return [self.random_chromo() for j in range(self.size)]

        def fitness(self, chromo):
            # larger is better, matched == 0
            return -sum(abs(c - t) for c, t in zip(chromo, self.target))

        def check_stop(self, fits_populations):
            self.counter += 1
            if self.counter % 1 == 0:
                best_match = list(sorted(fits_populations))[-1][1]
                fits = [f for f, ch in fits_populations]
                best = max(fits)
                worst = min(fits)
                ave = sum(fits) / len(fits)
                print(
                    "[G %3d] score=(%4d, %4d, %4d): %r" %
                    (self.counter, best, ave, worst,
                     self.chromo2text(best_match)))
                pass
            return self.counter >= self.limit

        def parents(self, fits_populations):
            while True:
                father = self.tournament(fits_populations)
                mother = self.tournament(fits_populations)
                yield (father, mother)
                pass
            pass

        def crossover(self, parents):
            father, mother = parents
            index1 = random.randint(1, len(self.target) - 2)
            index2 = random.randint(1, len(self.target) - 2)
            if index1 > index2: index1, index2 = index2, index1
            child1 = father[:index1] + mother[index1:index2] + father[index2:]
            child2 = mother[:index1] + father[index1:index2] + mother[index2:]
            return (child1, child2)

        def mutation(self, chromosome):
            index = random.randint(0, len(self.target) - 1)
            vary = random.randint(-5, 5)
            mutated = list(chromosome)
            mutated[index] += vary
            return mutated

        # internals
        def tournament(self, fits_populations):
            alicef, alice = self.select_random(fits_populations)
            bobf, bob = self.select_random(fits_populations)
            return alice if alicef > bobf else bob

        def select_random(self, fits_populations):
            return fits_populations[random.randint(0, len(fits_populations)-1)]

        def text2chromo(self, text):
            return [ord(ch) for ch in text]
        def chromo2text(self, chromo):
            return "".join(chr(max(1, min(ch, 255))) for ch in chromo)

        def random_chromo(self):
            return [random.randint(1, 255) for i in range(len(self.target))]
        pass

    GeneticAlgorithm(GuessText("Hello World!")).run()
    pass
# Out:
# [G   1] score=(-441, -860, -1401): 'z¾$c\\0ON\xad\x82\x8d\n'
# [G   2] score=(-443, -766, -1237): 'jtÌ`\x871\x99¤À\x82|\x1f'
# [G   3] score=(-356, -686, -1164): 'BS\x89\x80g\x0bSö\x87ªt\x11'
# [G   4] score=(-300, -611, -1027): 'O\x87pT_1h\x8e\x8bx\x85q'
# [G   5] score=(-285, -544, -855): 'BS3u\x9a!D]GEt\x11'
# [G   6] score=(-258, -490, -769): 'BS\x89a\x9a!%\x81\x90\x80t\x11'
# [G   7] score=(-238, -439, -666): 'BS\x8eu\x9a!up>xt\x11'
# [G   8] score=(-222, -396, -638): '>]b^_1hrTT&\x16'
# [G   9] score=(-224, -356, -681): '?2t\x8dg%ur\x87Tc\x02'
# [G  10] score=(-177, -315, -515): 'B|\x81xa+f\x80\x88ft\x13'
# [G  11] score=(-175, -286, -476): 'BSt\x8dg-Nr\x7fLt\x11'
# [G  12] score=(-149, -260, -401): 'B]us\\/HqfTt\x11'
# [G  13] score=(-138, -235, -352): 'F]bt_%f}f\\t\x11'
# [G  14] score=(-129, -213, -337): 'B[ttg\x0fVqTst\x11'
# [G  15] score=(-133, -194, -288): 'ERj\x80~%frfst\x11'
# [G  16] score=( -98, -180, -272): 'BSjlg\x1bNrjst\x11'
# [G  17] score=( -98, -166, -231): 'BSjlg\x1bNrjst\x11'
# [G  18] score=( -98, -155, -232): 'BSnlg\x1bNrjst\x11'
# [G  19] score=( -96, -145, -199): 'BVjle!fqqxt\x11'
# [G  20] score=( -91, -135, -199): 'B`tlg\x1bNrjst\x11'
# [G  21] score=( -90, -126, -164): 'B]mle!fqqxv\x11'
# [G  22] score=( -76, -118, -179): 'G]jlg Nqq\\t\x14'
# [G  23] score=( -79, -110, -148): 'G]jl~\x1bQqqst\x11'
# [G  24] score=( -76, -104, -139): 'B]jlk!Nqq^t\x14'
# [G  25] score=( -71,  -97, -134): 'G]jll\x1bPqq^t\x15'
# [G  26] score=( -71,  -91, -121): 'G]jll"Nrq^t\x15'
# [G  27] score=( -63,  -86, -115): 'G]jll\x1bNoqft\x15'
# [G  28] score=( -64,  -82, -111): 'G]jlg%Vrqst\x15'
# [G  29] score=( -57,  -77,  -96): 'G]jlk"Xtqkt\x11'
# [G  30] score=( -54,  -74,  -95): 'G]jll Vrqst\x15'
# [G  31] score=( -49,  -70,  -96): 'Gbjll Vrqst\x15'
# [G  32] score=( -45,  -66,  -90): 'Gbjll Vqqpt\x15'
# [G  33] score=( -45,  -63,  -82): 'Gbjll Vqqpt\x15'
# [G  34] score=( -42,  -60,  -74): 'Gbjll Vqqkt\x15'
# [G  35] score=( -41,  -57,  -73): 'G`mll Xoqkt\x15'
# [G  36] score=( -41,  -54,  -68): 'G`mll Xoqkt\x15'
# [G  37] score=( -40,  -51,  -66): 'G`kln\x1fXoqfo\x15'
# [G  38] score=( -37,  -49,  -62): 'Gckln!Voqkt\x15'
# [G  39] score=( -36,  -46,  -59): 'Gdkln!Voqkt\x15'
# [G  40] score=( -33,  -44,  -59): 'Gckln Xprkq\x15'
# [G  41] score=( -34,  -42,  -56): 'Gdkln Xorkt\x15'
# [G  42] score=( -28,  -41,  -54): 'Gdjlp Vnqkm\x17'
# [G  43] score=( -27,  -39,  -50): 'Gdmln Vnqmm\x17'
# [G  44] score=( -25,  -37,  -48): 'Gdmln Xorkm\x17'
# [G  45] score=( -25,  -35,  -45): 'Gdmln Vormm\x17'
# [G  46] score=( -25,  -33,  -44): 'Gdmln Vormm\x17'
# [G  47] score=( -23,  -31,  -43): 'Gdklp Vnqkm\x1b'
# [G  48] score=( -24,  -30,  -41): 'Gdkln Xnqnm\x1b'
# [G  49] score=( -23,  -28,  -40): 'Gdmln Worko\x1a'
# [G  50] score=( -21,  -27,  -34): 'Gdjlo Xorkm\x1b'
# [G  51] score=( -21,  -27,  -33): 'Gdkln Vorkm\x1b'
# [G  52] score=( -20,  -26,  -34): 'Gdklo Vorkj\x18'
# [G  53] score=( -20,  -25,  -32): 'Gdmln Voqlm\x1c'
# [G  54] score=( -18,  -24,  -32): 'Gdklo Voskj\x1b'
# [G  55] score=( -17,  -23,  -33): 'Hdmlo Workm\x1c'
# [G  56] score=( -17,  -22,  -31): 'Hdmlo Workm\x1c'
# [G  57] score=( -13,  -21,  -29): 'Gdklp Xorki\x1f'
# [G  58] score=( -12,  -21,  -27): 'Gdnlo Woqlf\x1c'
# [G  59] score=( -11,  -20,  -28): 'Gdklo Xormj!'
# [G  60] score=( -11,  -19,  -27): 'Gdmlo Xoqlj!'
# [G  61] score=( -10,  -18,  -26): 'Gdmlo Workj!'
# [G  62] score=(  -9,  -17,  -26): 'Gdllo Vorlj!'
# [G  63] score=( -10,  -15,  -24): 'Gekln Workj!'
# [G  64] score=(  -9,  -14,  -23): 'Geklo Workj!'
# [G  65] score=(  -8,  -13,  -21): 'Gemlo Vorke\x1e'
# [G  66] score=(  -6,  -12,  -21): 'Geklo Vorkf!'
# [G  67] score=(  -6,  -11,  -21): 'Gdmlo Voqle!'
# [G  68] score=(  -5,  -10,  -17): 'Gello Vorkf!'
# [G  69] score=(  -4,  -10,  -21): 'Gello Wprlf!'
# [G  70] score=(  -3,   -9,  -16): 'Gemlo Worle!'
# [G  71] score=(  -3,   -8,  -15): 'Gemlo Worle!'
# [G  72] score=(  -3,   -7,  -15): 'Gemlo Worle!'
# [G  73] score=(  -3,   -6,  -17): 'Gemlo Worle!'
# [G  74] score=(  -3,   -6,  -16): 'Gemlo Worle!'
# [G  75] score=(  -3,   -5,  -13): 'Idllo Worle!'
# [G  76] score=(  -2,   -5,  -13): 'Iello Worle!'
# [G  77] score=(  -2,   -4,  -15): 'Iello Worle!'
# [G  78] score=(  -2,   -4,  -10): 'Iello Worle!'
# [G  79] score=(  -1,   -4,  -12): 'Gello World!'
# [G  80] score=(  -2,   -3,  -10): 'Iello Worle!'
# [G  81] score=(  -2,   -3,  -13): 'Iello Worle!'
# [G  82] score=(  -1,   -3,  -11): 'Gello World!'
# [G  83] score=(  -1,   -2,   -8): 'Gello World!'
# [G  84] score=(  -1,   -2,   -9): 'Hello Worle!'
# [G  85] score=(  -1,   -2,   -8): 'Hello Worle!'
# [G  86] score=(  -1,   -2,   -9): 'Hello Worle!'
# [G  87] score=(  -1,   -2,   -7): 'Hello Worle!'
# [G  88] score=(  -1,   -2,   -9): 'Hello Worle!'
# [G  89] score=(   0,   -2,  -11): 'Hello World!'
# [G  90] score=(   0,   -2,   -8): 'Hello World!'
# [G  91] score=(  -1,   -2,   -7): 'Iello World!'
# [G  92] score=(  -1,   -1,   -8): 'Iello World!'
# [G  93] score=(   0,   -1,  -10): 'Hello World!'
# [G  94] score=(   0,   -1,  -11): 'Hello World!'
# [G  95] score=(   0,   -1,   -7): 'Hello World!'
# [G  96] score=(   0,   -1,   -7): 'Hello World!'
# [G  97] score=(   0,   -1,  -11): 'Hello World!'
# [G  98] score=(   0,   -1,   -7): 'Hello World!'
# [G  99] score=(   0,   -1,   -7): 'Hello World!'
# [G 100] score=(   0,   -1,   -6): 'Hello World!'
# [G 101] score=(   0,   -1,   -8): 'Hello World!'
# [G 102] score=(   0,   -1,   -9): 'Hello World!'
# [G 103] score=(   0,    0,   -7): 'Hello World!'
# [G 104] score=(   0,    0,   -6): 'Hello World!'
# [G 105] score=(   0,    0,   -6): 'Hello World!'
# [G 106] score=(   0,    0,   -7): 'Hello World!'
# [G 107] score=(   0,    0,   -7): 'Hello World!'
# [G 108] score=(   0,    0,   -6): 'Hello World!'
# [G 109] score=(   0,    0,   -8): 'Hello World!'
# [G 110] score=(   0,    0,   -8): 'Hello World!'
# [G 111] score=(   0,    0,   -7): 'Hello World!'
# [G 112] score=(   0,    0,   -5): 'Hello World!'
# [G 113] score=(   0,    0,   -6): 'Hello World!'
# [G 114] score=(   0,    0,   -7): 'Hello World!'
# [G 115] score=(   0,    0,   -7): 'Hello World!'
# [G 116] score=(   0,    0,   -9): 'Hello World!'
# [G 117] score=(   0,    0,   -8): 'Hello World!'
# [G 118] score=(   0,    0,   -5): 'Hello World!'
# [G 119] score=(   0,    0,   -8): 'Hello World!'
# [G 120] score=(   0,    0,   -7): 'Hello World!'
# [G 121] score=(   0,    0,   -7): 'Hello World!'
# [G 122] score=(   0,    0,   -8): 'Hello World!'
# [G 123] score=(   0,    0,   -7): 'Hello World!'
# [G 124] score=(   0,    0,   -7): 'Hello World!'
# [G 125] score=(   0,    0,   -7): 'Hello World!'
# [G 126] score=(   0,    0,   -6): 'Hello World!'
# [G 127] score=(   0,    0,   -5): 'Hello World!'
# [G 128] score=(   0,    0,   -8): 'Hello World!'
# [G 129] score=(   0,    0,   -8): 'Hello World!'
# [G 130] score=(   0,    0,   -5): 'Hello World!'
# [G 131] score=(   0,    0,   -6): 'Hello World!'
# [G 132] score=(   0,    0,   -6): 'Hello World!'
# [G 133] score=(   0,    0,   -5): 'Hello World!'
# [G 134] score=(   0,    0,   -5): 'Hello World!'
# [G 135] score=(   0,    0,   -9): 'Hello World!'
# [G 136] score=(   0,    0,   -7): 'Hello World!'
# [G 137] score=(   0,    0,   -6): 'Hello World!'
# [G 138] score=(   0,    0,   -7): 'Hello World!'
# [G 139] score=(   0,    0,   -7): 'Hello World!'
# [G 140] score=(   0,    0,   -7): 'Hello World!'
# [G 141] score=(   0,    0,   -5): 'Hello World!'
# [G 142] score=(   0,    0,   -8): 'Hello World!'
# [G 143] score=(   0,    0,   -5): 'Hello World!'
# [G 144] score=(   0,    0,   -5): 'Hello World!'
# [G 145] score=(   0,    0,   -7): 'Hello World!'
# [G 146] score=(   0,    0,   -6): 'Hello World!'
# [G 147] score=(   0,    0,   -5): 'Hello World!'
# [G 148] score=(   0,    0,   -8): 'Hello World!'
# [G 149] score=(   0,    0,   -6): 'Hello World!'
# [G 150] score=(   0,    0,   -5): 'Hello World!'
# [G 151] score=(   0,    0,   -9): 'Hello World!'
# [G 152] score=(   0,    0,   -7): 'Hello World!'
# [G 153] score=(   0,    0,   -8): 'Hello World!'
# [G 154] score=(   0,    0,   -8): 'Hello World!'
# [G 155] score=(   0,    0,   -8): 'Hello World!'
# [G 156] score=(   0,    0,   -6): 'Hello World!'
# [G 157] score=(   0,    0,   -8): 'Hello World!'
# [G 158] score=(   0,    0,   -7): 'Hello World!'
# [G 159] score=(   0,    0,   -7): 'Hello World!'
# [G 160] score=(   0,    0,   -5): 'Hello World!'
# [G 161] score=(   0,    0,   -7): 'Hello World!'
# [G 162] score=(   0,    0,   -6): 'Hello World!'
# [G 163] score=(   0,    0,   -5): 'Hello World!'
# [G 164] score=(   0,    0,   -8): 'Hello World!'
# [G 165] score=(   0,    0,   -8): 'Hello World!'
# [G 166] score=(   0,    0,   -5): 'Hello World!'
# [G 167] score=(   0,    0,   -5): 'Hello World!'
# [G 168] score=(   0,    0,   -8): 'Hello World!'
# [G 169] score=(   0,    0,   -9): 'Hello World!'
# [G 170] score=(   0,    0,   -6): 'Hello World!'
# [G 171] score=(   0,    0,   -7): 'Hello World!'
# [G 172] score=(   0,    0,   -8): 'Hello World!'
# [G 173] score=(   0,    0,   -7): 'Hello World!'
# [G 174] score=(   0,    0,   -8): 'Hello World!'
# [G 175] score=(   0,    0,   -9): 'Hello World!'
# [G 176] score=(   0,    0,   -6): 'Hello World!'
# [G 177] score=(   0,    0,   -9): 'Hello World!'
# [G 178] score=(   0,    0,   -5): 'Hello World!'
# [G 179] score=(   0,    0,   -7): 'Hello World!'
# [G 180] score=(   0,    0,   -5): 'Hello World!'
# [G 181] score=(   0,    0,   -5): 'Hello World!'
# [G 182] score=(   0,    0,   -5): 'Hello World!'
# [G 183] score=(   0,    0,   -7): 'Hello World!'
# [G 184] score=(   0,    0,   -5): 'Hello World!'
# [G 185] score=(   0,    0,   -8): 'Hello World!'
# [G 186] score=(   0,    0,  -10): 'Hello World!'
# [G 187] score=(   0,    0,  -10): 'Hello World!'
# [G 188] score=(   0,    0,   -6): 'Hello World!'
# [G 189] score=(   0,    0,   -5): 'Hello World!'
# [G 190] score=(   0,    0,   -9): 'Hello World!'
# [G 191] score=(   0,    0,   -7): 'Hello World!'
# [G 192] score=(   0,    0,   -6): 'Hello World!'
# [G 193] score=(   0,    0,   -5): 'Hello World!'
# [G 194] score=(   0,    0,   -7): 'Hello World!'
# [G 195] score=(   0,    0,   -9): 'Hello World!'
# [G 196] score=(   0,    0,   -5): 'Hello World!'
# [G 197] score=(   0,    0,   -7): 'Hello World!'
# [G 198] score=(   0,    0,   -7): 'Hello World!'
# [G 199] score=(   0,    0,   -7): 'Hello World!'
# [G 200] score=(   0,    0,   -7): 'Hello World!'

# %% [markdown]
# Fijaos como es capaz de llegar a la cadena "Hello World!" tras unas pocas generaciones!
#
# Esto también puede aplicarse a una red neuronal. Para ello, se puede hacer uso de una implementación disponible en Github: https://github.com/jliphard/DeepEvolve

# %% [markdown]
# Y os recomiendo que le echéis un ojo a estos dos enlaces en los que evolucionan una red neuronal con un GA. Aquí no nos da tiempo, pero son muy interesantes:
#
# ### Ejemplo GA para evolucionar NN:
#
# * https://blog.coast.ai/lets-evolve-a-neural-network-with-a-genetic-algorithm-code-included-8809bece164
# * https://github.com/harvitronix/neural-network-genetic-algorithm
